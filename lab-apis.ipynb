# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
my= "<80d7956c1baa4e13b4e4ec1755e487be>"
secret = "<6bc3391cd9924cbd8ee5013d4a7a9986>"

# %%
CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
# ...

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=50'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["Albums"] # Number of matches
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 results["tracks"]["Albums"]
#
# KeyError: 'Albums'

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#     'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#     'id': '4VIvfOurcf0vuLRxLkGnIG',
#     'name': 'Bradley Cooper',
#     'type': 'artist',
#     'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
# ...

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Lady Gaga

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '2rbDhOo9Fh61Bbu23T2qCk'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Always Remember Us This Way'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 81

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:2rbDhOo9Fh61Bbu23T2qCk'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.

# %%
def get_top_songs(artist_name):
    results = sp.search(q=artist_name, type='artist')
    info = results['artists']['items'][0]
    artist_id = info['id']
    top_tracks = sp.artist_top_tracks(artist_id, country='US')
    
    for track in top_tracks['tracks']:
        print(f"Track: {track['name']}")
    
    return top_tracks['tracks']


   
print('Ariana Grande top songs:')
print( get_top_songs('Ariana Grande'))
print('Britney Spears top songs: ')
print( get_top_songs('Britney Spears'))
print('Mily Cyrus top songs: ')
print( get_top_songs('Mily Cyrus'))
# Out:
# Ariana Grande top songs:
# Track: we can't be friends (wait for your love)
# Track: the boy is mine
# Track: intro (end of the world)
# Track: yes, and?
# Track: Save Your Tears (Remix) (with Ariana Grande) - Bonus Track
# Track: Die For You (with Ariana Grande) - Remix
# Track: One Last Time
# Track: 7 rings
# Track: Dangerous Woman
# Track: bye
# ...

# %%
def Get_artist_top_songs(artist_name):

    results = sp.search(q=artist_name, type='artist')
    info = results['artists']['items'][0]
    artist_id = info['id']
    top_tracks = sp.artist_top_tracks(artist_id, country='US')

    #top_tracks['tracks']
    for track in top_tracks['tracks']:
      print(track['name'])

Get_artist_top_songs('Ariana Grande')
# Out:
# we can't be friends (wait for your love)
# the boy is mine
# intro (end of the world)
# yes, and?
# Save Your Tears (Remix) (with Ariana Grande) - Bonus Track
# Die For You (with Ariana Grande) - Remix
# One Last Time
# 7 rings
# Dangerous Woman
# bye

# %%
Get_artist_top_songs('Britney Spears')
# Out:
# Toxic
# ...Baby One More Time
# Gimme More
# Oops!...I Did It Again
# Hold Me Closer
# Womanizer
# Circus
# Criminal
# If U Seek Amy
# I'm a Slave 4 U

# %%
Get_artist_top_songs('Miley Cyrus')
# Out:
# Flowers
# Party In The U.S.A.
# Angels Like You
# Wrecking Ball
# Nothing Breaks Like a Heart (feat. Miley Cyrus)
# II MOST WANTED
# We Can't Stop
# Used To Be Young
# The Climb
# Prisoner (feat. Dua Lipa)

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': '50 Hits in einer Playlist! Cover: GReeeN',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4jP4eebSWR9'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4jP4eebSWR9',
#     'id': '37i9dQZF1DX4jP4eebSWR9',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000203db8cc7e6240034e7eadf36',
#       'width': None}],
#     'name': 'Hot Hits Deutschland',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#C3F0C8',
#     'public': True,
# ...

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id ='5PZCLvCaN2ji6VZetGLaJ0'
playlist = sp.playlist(playlist_id)
playlist.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
print(playlist['owner']) 
print(playlist['tracks']) 
print(playlist['followers'])
# Out:
# My recommendation playlist
# Playlist created by the tutorial on developer.spotify.com
# {'display_name': 'Mustafa A Aldabbas', 'external_urls': {'spotify': 'https://open.spotify.com/user/21f3jb3bwocolc32z6vihldia'}, 'href': 'https://api.spotify.com/v1/users/21f3jb3bwocolc32z6vihldia', 'id': '21f3jb3bwocolc32z6vihldia', 'type': 'user', 'uri': 'spotify:user:21f3jb3bwocolc32z6vihldia'}
# ...

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# we can't be friends (wait for your love)
# Honey - Mura Masa Chill Remix
# Rush
# Holiday - Tame Impala Remix
# Got Me Started
# Bourgie Bourgie
# Show Me Some Love (feat. Sadie Walker)
# Prada (feat. D-Block Europe) - Acoustic Version
# It's Quiet Now (feat. Dope Earth Alien)
# Freak Me Now (with Róisín Murphy)

# %%
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Ariana Grande', 'Troye Sivan', 'Mura Masa', 'Confidence Man', 'Tame Impala', 'LF SYSTEM', 'Honey Dijon', 'Channel Tres', 'Sadie Walker', 'cassö', 'RAYE', 'D-Block Europe', 'Dope Earth Alien', 'Jessie Ware', 'Róisín Murphy']

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Take Me Home, Country Roads
# La Vie En Rose
# You Are My Sunshine
# Sunday Morning - Acoustic
# Too Good At Goodbyes - Acoustic
# True Colours
# I'm Not the Only One - Live from Spotify, London
# Cold Heart - Acoustic
# September Song - Guitar Acoustic
# Collide - Acoustic Version
# Baby One More Time - Recorded at Spotify Studios New York City
# If You Ever Wanna Be In Love - James Bay Spotify Session 2015
# When You Love Someone - Acoustic
# Rockabye - Acoustic Version
# Blinding Lights
# Ain't Nobody (Loves Me Better) - Acoustic
# Shape of You - Acoustic
# Little Talks
# Something Just Like This - Acoustic
# Linger
# Let It Go - James Bay Spotify Session 2015
# What About Us - Acoustic
# 1973 - Acoustic
# Heaven Is a Place on Earth
# Billie Jean
# Crazy in Love
# Perfect - Acoustic
# Wild Love - Acoustic
# Naked - Acoustic Version
# Firestone - Live Acoustic Version
# Can't Help Falling in Love
# Price Tag - Acoustic Version
# Fix You - Live
# ...

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lana Del Rey', 'Daniela Andrade', 'Jasmine Thompson', 'Maroon 5', 'Sam Smith', 'Tom Odell', 'Dua Lipa', 'Elton John', 'JP Cooper', 'Howie Day', 'Ed Sheeran', 'James Bay', 'James TW', 'The Mayries', 'Ouvindo', 'Julia Sheer', 'Jon D', 'Missy & Blonde', 'Julia Ross', 'Freedom Fry', 'Thomas Daniel', 'James Blunt', 'The Civil Wars', 'James Arthur', 'Kygo', 'Conrad Sewell', 'Kacey Musgraves', 'Jessie J', 'John Mayer', 'The Wind and The Wave', 'Megan Davies', 'Keelan Donovan', 'Halloran & Kate', 'Calum Scott', 'Lotte Kestner', 'Joy Williams', 'John Legend', 'Sixpence None The Richer', 'The Lumineers', 'Obadiah Parker', 'Frente!', 'Molly Parden', 'Hollow Hum', 'Lily Allen', 'Gavin James', 'Sara Farell', 'Daniel Powter', 'Joanna Wang', 'Sia', 'Niall Horan', 'William Fitzsimmons', 'Becca Adams', 'Lykke Li', 'Alex Cornell', 'Sarah Jarosz', 'Rachel Brown', 'Kyle Nachtigal', 'Clementine Duo', 'Arlo Parks', "Israel Kamakawiwo'ole", 'Rita Ora', 'Sunset & Highland', 'Jaclyn Davies', 'Francesco Yat
# ...

# %%
playlist_id1 = '5PZCLvCaN2ji6VZetGLaJ0'
palylist = sp.playlist(playlist_id1)
playlist.keys()
print(playlist['name'])
print(playlist['description'])
playlist['tracks']
# Out:
# My recommendation playlist
# Playlist created by the tutorial on developer.spotify.com
# {'href': 'https://api.spotify.com/v1/playlists/5PZCLvCaN2ji6VZetGLaJ0/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-07-04T12:30:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/21f3jb3bwocolc32z6vihldia'},
#     'href': 'https://api.spotify.com/v1/users/21f3jb3bwocolc32z6vihldia',
#     'id': '21f3jb3bwocolc32z6vihldia',
#     'type': 'user',
#     'uri': 'spotify:user:21f3jb3bwocolc32z6vihldia'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
# ...

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
def fetch_top_featured_playlists():
        featured_play_lists = sp.featured_playlists(limit=5)
        playlists = featured_play_lists['playlists']['items']
        for playlist in playlists:
                print(f"Playlist Name: {playlist['name']}")
                print(f"Playlist ID: {playlist['id']}")
                print()

fetch_top_featured_playlists()
# Out:
# Playlist Name: Hot Hits Deutschland
# Playlist ID: 37i9dQZF1DX4jP4eebSWR9
#
# Playlist Name: Deutschrap Brandneu
# Playlist ID: 37i9dQZF1DWSTqUqJcxFk6
#
# Playlist Name: Modus Mio
# Playlist ID: 37i9dQZF1DX36edUJpD76c
#
# Playlist Name: Summer House 2024
# Playlist ID: 37i9dQZF1DX05r4Oy3Ln97
#
# Playlist Name: New Music Friday Deutschland
# Playlist ID: 37i9dQZF1DWUW2bvSkjcJ6

# %%
playlist_id ='37i9dQZF1DX4jP4eebSWR9'
playlist = sp.playlist(playlist_id)
playlist.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
print(playlist['owner']) 
print(playlist['tracks']) 
print(playlist['followers'])
# Out:
# Hot Hits Deutschland
# 50 Hits in einer Playlist! Cover: GReeeN
# {'display_name': 'Spotify', 'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'}, 'href': 'https://api.spotify.com/v1/users/spotify', 'id': 'spotify', 'type': 'user', 'uri': 'spotify:user:spotify'}
# ...

# %%
def Playlist_tracks_names(tracks):
    tracks_names = []
    tracks = sp.playlist_tracks(playlist_id)
    for item in tracks['items']:
        track = item['track']
        tracks_names.append(track['name'])
    return tracks_names 
tracks_names= Playlist_tracks_names(tracks)
tracks_names
# Out:
# ['Panama',
#  'ZEIT, DASS SICH WAS DREHT',
#  'Baddies',
#  'Liebe in Stereo',
#  'NIGHTS LIKE THIS',
#  'Wunder',
#  'VEMPA',
#  'Move',
#  'Dieser Sommer',
#  'Randali',
#  'Fall Back',
#  'Beifahrer',
#  'Mittelmeer',
#  'Irgendwas klopft',
#  'Houdini',
#  'Pedro',
#  'JUNGE BALLER',
#  'Chaos',
#  'Tough',
#  'Pistoleta',
#  'Abenteuerland',
#  'Major Tom (Völlig losgelöst) - 2022 Remaster',
#  'Mach die Augen auf',
#  'NaNa',
#  'wie du manchmal fehlst',
#  'Espresso',
#  'Mama hat gesagt',
#  'Thank You (Not So Bad)',
#  'Gata Only',
#  'DEUTSCHLAND 🇩🇪',
#  'Mwaki',
#  'Simple Life',
#  'Stargazing',
#  'Verschwendete Zeit',
#  'Vielleicht Vielleicht',
#  'A Bar Song (Tipsy)',
#  'BIRDS OF A FEATHER',
#  'i like the way you kiss me',
#  'Vois sur ton chemin - Techno Mix',
#  "I Don't Wanna Wait",
#  'BAND4BAND (feat. Lil Baby)',
#  'Belong Together',
#  'Please Please Please',
#  'Too Sweet',
#  "TEXAS HOLD 'EM",
#  'MILLION DOLLAR BABY',
# ...

# %%
def artists_names_list(track):
    artists_list = []
    for track_item in tracks['items']:
        track = track_item['track']
        for artist in track['artists']:
            artist_name = artist['name']
            if artist_name not in artists_list:  # This ensures each artist is added only once
                artists_list.append(artist_name)
    return artists_list
   
artists_list = artists_names_list(track)
artists_list
# Out:
# ['GReeeN',
#  '$OHO BANI',
#  'Herbert Grönemeyer',
#  'Ericson',
#  'Aitch',
#  'Luciano',
#  'Baby B3ns',
#  'Yung Hurn',
#  'The Kid LAROI',
#  'AYLIVA',
#  'Apache 207',
#  'FOURTY',
#  'Bausa',
#  'Adam Port',
#  'Stryv',
#  'Keinemusik',
#  'Orso',
#  'Malachiii',
#  'Tream',
#  'treamiboii',
#  'Chapo102',
#  'Nina Chuba',
#  'Lithe',
#  'Pashanim',
#  'CIVO',
#  'Montez',
#  'Eminem',
#  'Jaxomy',
#  'Agatino Romero',
#  'Raffaella Carrà',
#  '6PM RECORDS',
#  'Ski Aggu',
#  'Haaland936',
#  'SIRA',
#  'LEA',
#  'Dhurata Dora',
#  'Quavo',
#  'Lana Del Rey',
#  'Olexesh',
#  'Ataypapi',
#  'ilo 7araga',
#  'FiNCH',
#  'SDP',
#  'Phil The Beat',
#  'Peter Schilling',
#  'Lune',
#  'Kauta',
#  'Zartmann',
#  'Dauner',
#  'Sabrina Carpenter',
#  'Sido',
#  'Esther Graf',
#  'Dimitri Vegas & Like Mike',
#  'Tiësto',
#  'Dido',
#  'W&W',
#  'Dimitri Vegas',
#  'Like Mike',
#  'FloyyMenor',
#  'Cris Mj',
#  'Ikkimel',
#  'Zerb',
#  'Sofiya Nzau',
#  'Leony',
#  'Myles Smith',
# ...

# %%
    # Create a dictionary from track names and artist names
track_artist_list_dict = dict(zip(tracks_names,artists_list ))
track_artist_list_dict
# Out:
# {'Panama': 'GReeeN',
#  'ZEIT, DASS SICH WAS DREHT': '$OHO BANI',
#  'Baddies': 'Herbert Grönemeyer',
#  'Liebe in Stereo': 'Ericson',
#  'NIGHTS LIKE THIS': 'Aitch',
#  'Wunder': 'Luciano',
#  'VEMPA': 'Baby B3ns',
#  'Move': 'Yung Hurn',
#  'Dieser Sommer': 'The Kid LAROI',
#  'Randali': 'AYLIVA',
#  'Fall Back': 'Apache 207',
#  'Beifahrer': 'FOURTY',
#  'Mittelmeer': 'Bausa',
#  'Irgendwas klopft': 'Adam Port',
#  'Houdini': 'Stryv',
#  'Pedro': 'Keinemusik',
#  'JUNGE BALLER': 'Orso',
#  'Chaos': 'Malachiii',
#  'Tough': 'Tream',
#  'Pistoleta': 'treamiboii',
#  'Abenteuerland': 'Chapo102',
#  'Major Tom (Völlig losgelöst) - 2022 Remaster': 'Nina Chuba',
#  'Mach die Augen auf': 'Lithe',
#  'NaNa': 'Pashanim',
#  'wie du manchmal fehlst': 'CIVO',
#  'Espresso': 'Montez',
#  'Mama hat gesagt': 'Eminem',
#  'Thank You (Not So Bad)': 'Jaxomy',
#  'Gata Only': 'Agatino Romero',
#  'DEUTSCHLAND 🇩🇪': 'Raffaella Carrà',
#  'Mwaki': '6PM RECORDS',
#  'Simple Life': 'Ski Aggu',
# ...
